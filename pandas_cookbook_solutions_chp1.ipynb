# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
#df - table with rows and cols
#read_csv() to read the df as an object
movies = pd.read_csv('data/movie.csv')
movies.head(10) #display first n rows
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
# 5  Color     Andrew Stanton                   462.0     132.0
# 6  Color          Sam Raimi                   392.0     156.0
# 7  Color       Nathan Greno                   324.0     100.0
# 8  Color        Joss Whedon                   635.0     141.0
# 9  Color        David Yates                   375.0     153.0
#
#    director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                      0.0                   855.0   Joel David Moore
# 1                    563.0                  1000.0      Orlando Bloom
# 2                      0.0                   161.0       Rory Kinnear
# ...

# %%
#each df has 3 attributes index, cols and its values
indexes = movies.index  
columns = movies.columns 
values = movies.values 

#index === columns --> spread across different axes

print(indexes)
print(columns)
print(values)
print(type(indexes))
print(type(columns))
print(type(values))
print([cls.__name__ for cls in pd.Index.__subclasses__()]) #listing indexes within the pd.Index object
#index objects are implemeted using hash tables
#index ~ python sets but indexes can be ordered with duplicates allowed
#RangeIndex ~ python range() --> doesnt load entire seq in memory and its defined by start, stop and step
#Pandas indexes, values and data return an ndarray
# Out:
# RangeIndex(start=0, stop=4916, step=1)
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')
# [['Color' 'James Cameron' 723.0 ... 7.9 1.78 33000]
#  ['Color' 'Gore Verbinski' 302.0 ... 7.1 2.35 0]
#  ['Color' 'Sam Mendes' 602.0 ... 6.8 2.35 85000]
#  ...
#  ['Color' 'Benjamin Roberds' 13.0 ... 6.3 nan 16]
#  ['Color' 'Daniel Hsia' 14.0 ... 6.3 2.35 660]
#  ['Color' 'Jon Gunn' 43.0 ... 6.6 1.85 456]]
# <class 'pandas.core.indexes.range.RangeIndex'>
# ...

# %%
director = movies['director_name']
actor_1_fb_likes = movies['actor_1_facebook_likes']

director.head()
actor_1_fb_likes.head()
director.value_counts()
# Out:
# Steven Spielberg        26
# Woody Allen             22
# Clint Eastwood          20
# Martin Scorsese         20
# Spike Lee               16
# Ridley Scott            16
# Renny Harlin            15
# Steven Soderbergh       15
# Tim Burton              14
# Oliver Stone            14
# Robert Rodriguez        13
# Robert Zemeckis         13
# Ron Howard              13
# Joel Schumacher         13
# Barry Levinson          13
# Brian De Palma          12
# Michael Bay             12
# Kevin Smith             12
# Tony Scott              12
# Francis Ford Coppola    11
# Sam Raimi               11
# Rob Reiner              11
# Richard Linklater       11
# Chris Columbus          11
# Shawn Levy              11
# Richard Donner          11
# David Fincher           10
# John Carpenter          10
# Paul W.S. Anderson      10
# John McTiernan          10
#                         ..
# Qasim Basir              1
# Mitchell Altieri         1
# Alex Zamm                1
# ...

# %%
director.size
director.shape
len(director)
# Out:
# 4916

# %%
actor_1_fb_likes.min(), actor_1_fb_likes.max(), \
actor_1_fb_likes.mean(), actor_1_fb_likes.median(), \
actor_1_fb_likes.std(), actor_1_fb_likes.sum()
# Out:
# (0.0, 640000.0, 6494.488490527602, 982.0, 15106.986883848309, 31881444.0)

# %%
#collection of all statistics
#quantiles help in dividinga distribution such that there is a given proportion of observation below the quantile
actor_1_fb_likes.describe(),  \
actor_1_fb_likes.quantile(.2)
# Out:
# (count      4909.000000
#  mean       6494.488491
#  std       15106.986884
#  min           0.000000
#  25%         607.000000
#  50%         982.000000
#  75%       11000.000000
#  max      640000.000000
#  Name: actor_1_facebook_likes, dtype: float64, 510.0)

# %%
director.isnull()
director.fillna(0)  #fillna replaces all the missing values with the placeholder
#similarly there is dropna
# Out:
# 0            James Cameron
# 1           Gore Verbinski
# 2               Sam Mendes
# 3        Christopher Nolan
# 4              Doug Walker
# 5           Andrew Stanton
# 6                Sam Raimi
# 7             Nathan Greno
# 8              Joss Whedon
# 9              David Yates
# 10             Zack Snyder
# 11            Bryan Singer
# 12            Marc Forster
# 13          Gore Verbinski
# 14          Gore Verbinski
# 15             Zack Snyder
# 16          Andrew Adamson
# 17             Joss Whedon
# 18            Rob Marshall
# 19        Barry Sonnenfeld
# 20           Peter Jackson
# 21               Marc Webb
# 22            Ridley Scott
# 23           Peter Jackson
# 24             Chris Weitz
# 25           Peter Jackson
# 26           James Cameron
# 27           Anthony Russo
# 28              Peter Berg
# 29         Colin Trevorrow
#                ...
# 4886            Eric Eason
# 4887              Uwe Boll
# 4888     Richard Linklater
# ...

# %%
imdb_score = movies['imdb_score']
imdb_score
#pandas uses the same vectorization concept borrowed from Numpy library
# Out:
# 0       7.9
# 1       7.1
# 2       6.8
# 3       8.5
# 4       7.1
# 5       6.6
# 6       6.2
# 7       7.8
# 8       7.5
# 9       7.5
# 10      6.9
# 11      6.1
# 12      6.7
# 13      7.3
# 14      6.5
# 15      7.2
# 16      6.6
# 17      8.1
# 18      6.7
# 19      6.8
# 20      7.5
# 21      7.0
# 22      6.7
# 23      7.9
# 24      6.1
# 25      7.2
# 26      7.7
# 27      8.2
# 28      5.9
# 29      7.0
#        ...
# 4886    7.0
# 4887    6.3
# 4888    7.1
# 4889    4.8
# 4890    3.3
# 4891    6.9
# 4892    4.6
# 4893    3.0
# 4894    6.6
# 4895    7.4
# 4896    6.2
# 4897    4.0
# 4898    6.1
# 4899    6.9
# 4900    7.5
# 4901    6.7
# 4902    7.4
# 4903    6.1
# 4904    5.4
# 4905    6.4
# 4906    7.0
# 4907    6.3
# 4908    6.9
# 4909    7.8
# 4910    6.4
# 4911    7.7
# 4912    7.5
# 4913    6.3
# 4914    6.3
# 4915    6.6
# Name: imdb_score, Length: 4916, dtype: float64

# %%
#Chaining
actor_1_fb_likes.value_counts().head(3) #chaining 1
# Out:
# 1000.0     436
# 11000.0    206
# 2000.0     189
# Name: actor_1_facebook_likes, dtype: int64

# %%
director.value_counts().head(3) #chaining 2
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Clint Eastwood      20
# Name: director_name, dtype: int64

# %%
actor_1_fb_likes.isnull().sum() #count number of missing values
actor_1_fb_likes.fillna(0).astype(int).head() #filling null values with 0 as int
actor_1_fb_likes.fillna(0).astype(int).mean()
# Out:
# 6485.240846216436

# %%
#Indexing
movies_ci_1 = movies.set_index('movie_title') #index provides a label for each row
movies_ci_2 = movies.set_index('director_name')
movies_ci_2

movies_ci_3 = pd.read_csv('data/movie.csv', index_col = 'movie_title')
movies_ci_3
#set_index() and index_col drops the index column from the df. It is possible to keep the index col in df with set_index by settting drop param to false
# Out:
#                                                        color  \
# movie_title
# Avatar                                                 Color
# Pirates of the Caribbean: At World's End               Color
# Spectre                                                Color
# The Dark Knight Rises                                  Color
# Star Wars: Episode VII - The Force Awakens               NaN
# John Carter                                            Color
# Spider-Man 3                                           Color
# Tangled                                                Color
# Avengers: Age of Ultron                                Color
# Harry Potter and the Half-Blood Prince                 Color
# Batman v Superman: Dawn of Justice                     Color
# Superman Returns                                       Color
# Quantum of Solace                                      Color
# Pirates of the Caribbean: Dead Man's Chest             Color
# ...

# %%
#Renaming
to_rename = pd.read_csv('data/movie.csv', index_col = 'movie_title')
id_rnm = {'Spectre' : 'NYSM', 'Tangled': 'Good Will Hunting'} # {old_idx1 : new_idx1, old_idx2 : new_idx2}
renamed = to_rename.rename(index = id_rnm) #for columns --> columns = col_rnm
renamed
# Out:
#                                                        color  \
# movie_title
# Avatar                                                 Color
# Pirates of the Caribbean: At World's End               Color
# NYSM                                                   Color
# The Dark Knight Rises                                  Color
# Star Wars: Episode VII - The Force Awakens               NaN
# John Carter                                            Color
# Spider-Man 3                                           Color
# Good Will Hunting                                      Color
# Avengers: Age of Ultron                                Color
# Harry Potter and the Half-Blood Prince                 Color
# Batman v Superman: Dawn of Justice                     Color
# Superman Returns                                       Color
# Quantum of Solace                                      Color
# Pirates of the Caribbean: Dead Man's Chest             Color
# ...

# %%
#alternative renaming

idxs_rnm = to_rename.index
cols_rnm = to_rename.columns

idxs_rnm = idxs_rnm.tolist()
cols_rnm = cols_rnm.tolist()

idxs_rnm[0] = 'ABCD'
idxs_rnm[1] = 'EFGH'
cols_rnm[0] = 'QWER'
cols_rnm[1] = 'TYUI'

#print(idxs_rnm, cols_rnm)
to_rename.index = idxs_rnm
to_rename.columns = cols_rnm
print(to_rename)
# Out:
#                                                         QWER  \
# ABCD                                                   Color
# EFGH                                                   Color
# Spectre                                                Color
# The Dark Knight Rises                                  Color
# Star Wars: Episode VII - The Force Awakens               NaN
# John Carter                                            Color
# Spider-Man 3                                           Color
# Tangled                                                Color
# Avengers: Age of Ultron                                Color
# Harry Potter and the Half-Blood Prince                 Color
# Batman v Superman: Dawn of Justice                     Color
# Superman Returns                                       Color
# Quantum of Solace                                      Color
# Pirates of the Caribbean: Dead Man's Chest             Color
# ...

# %%
#Creating and deleting colmns from df
created = pd.read_csv('data/movie.csv')
created['has_seen'] = 0 #by assigning scalar value
created['all_likes'] = (created['director_facebook_likes'] + created['actor_1_facebook_likes'] + created['actor_2_facebook_likes'] + created['actor_3_facebook_likes']) #assigning values of other columns
created.head()
created['all_likes'].isnull().sum()
created['all_likes'] = created['all_likes'].fillna(0)
created['is_greater_total_cast_likes'] = created['cast_total_facebook_likes'] >= created['all_likes']
created['is_greater_total_cast_likes'].all() #all returns true over an axis

#dropping all_likes and including only actors
created = created.drop(['all_likes'], axis = 1)
created['all_actors_likes'] = (created['actor_1_facebook_likes'] + created['actor_2_facebook_likes'] + created['actor_3_facebook_likes']) #assigning values of other columns
created.head()
#created['all_actors_likes'].isnull().sum()
created['all_actors_likes'] = created['all_actors_likes'].fillna(0)
created['is_greater_total_cast_likes'] = created['cast_total_facebook_likes'] >= created['all_actors_likes']
created['is_greater_total_cast_likes'].all() #all returns boolean over an axis
created['%of_fb_likes_from_actor_likes'] = (created['is_greater_total_cast_likes'] / created['all_actors_likes'])
created.head()
created['%of_fb_likes_from_actor_likes'].min(), created['%of_fb_likes_from_actor_likes'].max()
# Out:
# (1.5267175572519084e-06, inf)
