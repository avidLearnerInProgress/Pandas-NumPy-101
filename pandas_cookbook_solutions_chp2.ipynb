# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt

# %%
movie = pd.read_csv('data/movie.csv')
movie_actor_director = movie[[
    'actor_1_name', 'actor_2_name',
    'actor_3_name', 'director_name'
]]
movie_actor_director.head()
# Out:
#       actor_1_name      actor_2_name          actor_3_name      director_name
# 0      CCH Pounder  Joel David Moore             Wes Studi      James Cameron
# 1      Johnny Depp     Orlando Bloom        Jack Davenport     Gore Verbinski
# 2  Christoph Waltz      Rory Kinnear      Stephanie Sigman         Sam Mendes
# 3        Tom Hardy    Christian Bale  Joseph Gordon-Levitt  Christopher Nolan
# 4      Doug Walker        Rob Walker                   NaN        Doug Walker

# %%
#selecting single column as dataframe rather than series
#usually single column is selected with string resulting in series
movie_actor_director[['actor_1_name']].head() 
#movie_actor_director['actor_1_name'].head() --> This gives just a series of data instead of column
# Out:
#       actor_1_name
# 0      CCH Pounder
# 1      Johnny Depp
# 2  Christoph Waltz
# 3        Tom Hardy
# 4      Doug Walker

# %%
movie = pd.read_csv('data/movie.csv', index_col = 'movie_title')
movie.get_dtype_counts()
# Out:
# float64    13
# int64       3
# object     11
# dtype: int64

# %%
movie.select_dtypes(include = ['int']).head()#select only integer columns
# Out:
# Empty DataFrame
# Columns: []
# Index: [Avatar, Pirates of the Caribbean: At World's End, Spectre, The Dark Knight Rises, Star Wars: Episode VII - The Force Awakens]

# %%
movie.select_dtypes(include = ['number']).head() #selecting all numeric columns
# Out:
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
#
#                                             director_facebook_likes  \
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         0.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
#
# ...

# %%
#select with filter 
movie.filter(like = 'facebook').head() #searching through exact match string
movie.filter(regex = '\d').head() #searching through regex
# Out:
#                                             actor_3_facebook_likes  \
# movie_title
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# Spectre                                                      161.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                     NaN
#
#                                                 actor_2_name  \
# movie_title
# Avatar                                      Joel David Moore
# Pirates of the Caribbean: At World's End       Orlando Bloom
# Spectre                                         Rory Kinnear
# The Dark Knight Rises                         Christian Bale
# Star Wars: Episode VII - The Force Awakens        Rob Walker
#
#                                             actor_1_facebook_likes  \
# movie_title
# Avatar                                                      1000.0
# ...

# %%
movie.isnull().sum().head()
movie.isnull().sum().sum()
movie.isnull().any().any()
# Out:
# True

# %%
movie.select_dtypes(['object']).fillna('').min()
# Out:
# color
# director_name
# actor_2_name
# genres                                                        Action
# actor_1_name
# actor_3_name
# plot_keywords
# movie_imdb_link    http://www.imdb.com/title/tt0006864/?ref_=fn_t...
# language
# country
# content_rating
# dtype: object

# %%
college = pd.read_csv('data/college.csv')
college_ugds = college.filter(like = 'UGDS_')
college_ugds.head()
# Out:
#    UGDS_WHITE  UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# 0      0.0333      0.9353     0.0055      0.0019     0.0024     0.0019
# 1      0.5922      0.2600     0.0283      0.0518     0.0022     0.0007
# 2      0.2990      0.4192     0.0069      0.0034     0.0000     0.0000
# 3      0.6988      0.1255     0.0382      0.0376     0.0143     0.0002
# 4      0.0158      0.9208     0.0121      0.0019     0.0010     0.0006
#
#    UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# 0     0.0000    0.0059     0.0138
# 1     0.0368    0.0179     0.0100
# 2     0.0000    0.0000     0.2715
# 3     0.0172    0.0332     0.0350
# 4     0.0098    0.0243     0.0137

# %%
(college_ugds + .00501).head()
# Out:
#    UGDS_WHITE  UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# 0     0.03831     0.94031    0.01051     0.00691    0.00741    0.00691
# 1     0.59721     0.26501    0.03331     0.05681    0.00721    0.00571
# 2     0.30401     0.42421    0.01191     0.00841    0.00501    0.00501
# 3     0.70381     0.13051    0.04321     0.04261    0.01931    0.00521
# 4     0.02081     0.92581    0.01711     0.00691    0.00601    0.00561
#
#    UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# 0    0.00501   0.01091    0.01881
# 1    0.04181   0.02291    0.01501
# 2    0.00501   0.00501    0.27651
# 3    0.02221   0.03821    0.04001
# 4    0.01481   0.02931    0.01871

# %%
((college_ugds + .00501) //.01 / 100).head()
# Out:
#    UGDS_WHITE  UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# 0        0.03        0.94       0.01        0.00       0.00        0.0
# 1        0.59        0.26       0.03        0.05       0.00        0.0
# 2        0.30        0.42       0.01        0.00       0.00        0.0
# 3        0.70        0.13       0.04        0.04       0.01        0.0
# 4        0.02        0.92       0.01        0.00       0.00        0.0
#
#    UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# 0       0.00      0.01       0.01
# 1       0.04      0.02       0.01
# 2       0.00      0.00       0.27
# 3       0.02      0.03       0.04
# 4       0.01      0.02       0.01

# %%
((college_ugds + 0.001).round(2) == ((college_ugds + .00501) //.01 / 100)).head()
# Out:
#    UGDS_WHITE  UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# 0        True        True       True        True       True       True
# 1        True        True       True        True       True       True
# 2        True        True       True        True       True       True
# 3        True        True       True        True      False       True
# 4        True        True       True        True       True       True
#
#    UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# 0       True      True       True
# 1       True      True       True
# 2       True      True       True
# 3       True      True       True
# 4       True     False       True

# %%
college_self_compare = college_ugds == college_ugds
college_self_compare.head()
# Out:
#    UGDS_WHITE  UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# 0        True        True       True        True       True       True
# 1        True        True       True        True       True       True
# 2        True        True       True        True       True       True
# 3        True        True       True        True       True       True
# 4        True        True       True        True       True       True
#
#    UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# 0       True      True       True
# 1       True      True       True
# 2       True      True       True
# 3       True      True       True
# 4       True      True       True

# %%
college_self_compare.all()
# Out:
# UGDS_WHITE    False
# UGDS_BLACK    False
# UGDS_HISP     False
# UGDS_ASIAN    False
# UGDS_AIAN     False
# UGDS_NHPI     False
# UGDS_2MOR     False
# UGDS_NRA      False
# UGDS_UNKN     False
# dtype: bool

# %%
college_ugds.isnull().sum()
# Out:
# UGDS_WHITE    661
# UGDS_BLACK    661
# UGDS_HISP     661
# UGDS_ASIAN    661
# UGDS_AIAN     661
# UGDS_NHPI     661
# UGDS_2MOR     661
# UGDS_NRA      661
# UGDS_UNKN     661
# dtype: int64

# %%
college_ugds.equals(college_ugds)
# Out:
# True

# %%
#transposing using axis
college = pd.read_csv('data/college.csv', index_col = 'INSTNM')
colleg_ugds = college.filter(like = 'UGDS_')
college_ugds
# Out:
#       UGDS_WHITE  UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# 0         0.0333      0.9353     0.0055      0.0019     0.0024     0.0019
# 1         0.5922      0.2600     0.0283      0.0518     0.0022     0.0007
# 2         0.2990      0.4192     0.0069      0.0034     0.0000     0.0000
# 3         0.6988      0.1255     0.0382      0.0376     0.0143     0.0002
# 4         0.0158      0.9208     0.0121      0.0019     0.0010     0.0006
# 5         0.7825      0.1119     0.0348      0.0106     0.0038     0.0009
# 6         0.7255      0.2613     0.0044      0.0025     0.0044     0.0000
# 7         0.7823      0.1200     0.0191      0.0053     0.0157     0.0010
# 8         0.5328      0.3376     0.0074      0.0221     0.0044     0.0016
# 9         0.8507      0.0704     0.0248      0.0227     0.0074     0.0000
# 10        0.7983      0.1102     0.0195      0.0517     0.0102     0.0000
# 11        0.4661      0.4372     0.0492      0.0127     0.0023     0.0035
# ...

# %%
college_ugds.count()
# Out:
# UGDS_WHITE    6874
# UGDS_BLACK    6874
# UGDS_HISP     6874
# UGDS_ASIAN    6874
# UGDS_AIAN     6874
# UGDS_NHPI     6874
# UGDS_2MOR     6874
# UGDS_NRA      6874
# UGDS_UNKN     6874
# dtype: int64

# %%
college_ugds.count(axis='columns').head()  #counting number of non missing values
#axis 0 - rows, 1 - columns
#college_ugds.head()
# Out:
# 0    9
# 1    9
# 2    9
# 3    9
# 4    9
# dtype: int64

# %%
college_ugds.sum(axis='columns').head()  #counting number of non missing values
#when axis = 1 the operations is performed row wise
#when axis = 0 its performed column wise
# Out:
# 0    1.0000
# 1    0.9999
# 2    1.0000
# 3    1.0000
# 4    1.0000
# dtype: float64

# %%
colleg_ugds.median().head()
# Out:
# UGDS_WHITE    0.55570
# UGDS_BLACK    0.10005
# UGDS_HISP     0.07140
# UGDS_ASIAN    0.01290
# UGDS_AIAN     0.00260
# dtype: float64

# %%
#does cummulative sum #iterates over each row and finds sum across columns
college_ugs_cumsum = college_ugds.cumsum(axis = 1)
college_ugs_cumsum.head()
# Out:
#    UGDS_WHITE  UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# 0      0.0333      0.9686     0.9741      0.9760     0.9784     0.9803
# 1      0.5922      0.8522     0.8805      0.9323     0.9345     0.9352
# 2      0.2990      0.7182     0.7251      0.7285     0.7285     0.7285
# 3      0.6988      0.8243     0.8625      0.9001     0.9144     0.9146
# 4      0.0158      0.9366     0.9487      0.9506     0.9516     0.9522
#
#    UGDS_2MOR  UGDS_NRA  UGDS_UNKN
# 0     0.9803    0.9862     1.0000
# 1     0.9720    0.9899     0.9999
# 2     0.7285    0.7285     1.0000
# 3     0.9318    0.9650     1.0000
# 4     0.9620    0.9863     1.0000

# %%
colleges = pd.read_csv("data/college.csv", index_col = 'INSTNM')
colleges_ugds = college.filter(like='UGDS_')

# %%
college_ugds.isnull().sum(axis=1).sort_values(ascending=False).head()
# Out:
# 7534    9
# 3323    9
# 1997    9
# 1662    9
# 220     9
# dtype: int64

# %%
college_ugds_dropped = college_ugds.dropna(how='all') #how all ensures that it drops only if all of the param are missing

# %%
college_ugds_dropped.isnull().sum().sum()
# Out:
# 0

# %%
college_ugds_dropped.ge(.15)
# Out:
#       UGDS_WHITE  UGDS_BLACK  UGDS_HISP  UGDS_ASIAN  UGDS_AIAN  UGDS_NHPI  \
# 0          False        True      False       False      False      False
# 1           True        True      False       False      False      False
# 2           True        True      False       False      False      False
# 3           True       False      False       False      False      False
# 4          False        True      False       False      False      False
# 5           True       False      False       False      False      False
# 6           True        True      False       False      False      False
# 7           True       False      False       False      False      False
# 8           True        True      False       False      False      False
# 9           True       False      False       False      False      False
# 10          True       False      False       False      False      False
# 11          True        True      False       False      False      False
# ...

# %%
diversity_metric = college_ugds_dropped.ge(.15).sum(axis='columns')
diversity_metric.head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    1
# 4    1
# dtype: int64

# %%
diversity_metric.value_counts() #2 schools have more than 15% in 5 race categories
# Out:
# 1    3042
# 2    2884
# 3     876
# 4      63
# 0       7
# 5       2
# dtype: int64

# %%
diversity_metric.sort_values(ascending = False).head()
# Out:
# 6046    5
# 4646    5
# 5142    4
# 6259    4
# 2357    4
# dtype: int64

# %%
(college_ugds_dropped > 0.1).all(axis = 1).any()
# Out:
# False
